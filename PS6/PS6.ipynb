# %% [markdown]
# # Market Analysis: Problem Set 6

# %% [markdown]
# **Submission guidelines:**
#
# 1. Submission requires downloading and saving your ipynb file as .html file with the filename, studentID-studentName. For example, 407510073-束良鴻.
# 2. Removing all irrelevant code blocks.
# 3. Email the html file to your TA. (E-mail address: p4896p4896@gmail.com)
# 4. Failing to submit in a correct format will result in a reduction of **20 points**.
# 5. Deadline: **6/9 Thur. 3 p.m.**
# 6. No late submission will be accepted.

# %% [markdown]
# In this problem set, you will be applying web scraping techniques taught in class on IMDB website. IMDB is an online database of information related to films, television programs, home videos, video games, and streaming content online. As of January 2020, IMDb has approximately 6.5 million titles (including episodes) and 10.4 million personalities in its database, as well as 83 million registered users. It is the leading website which provides ratings and reviews from audience all over the world. If you are interested in analyzing data about movies, you certainly need to look into IMDB.
#
# In this question, please refer to this web address, https://www.imdb.com/search/title/?groups=top_1000&sort=user_rating. The main goal here is to scrape relevant information of top-1000 high-rated movies.
#
# There are several useful hints and requirements.
#
# 1. You need to scrape 8 relevant variables and store them in separate columns of your dataframe. The column names are provided as **name, year, certificate, runtime, genre, rating, votes, and gross.**
#
# 2. We are interested in top-1000 highest-rated movies on imdb. And the web page only return **50** of them on each page. So, you need to scrape through different webpages and combine the information together.
#
# 3. For some movies, they do not have the information available on the web page. For example, some movies do not have ‘gross’. You will need to handle this issue.
#
# 4. I have provided a random sample of 10 movies. Your final result should resemble the dataframe.

# %%
df.sample(10)
# Out:
#             name        year certificate  runtime  \
# 226        戀戀大吉嶺      (2012)       PG-12  151 min
# 768  芝加哥七人案：驚世審判      (2020)           R  129 min
# 514        三不管地帶  (I) (2001)           R   98 min
# 103       心中的小星星      (2007)          PG  165 min
# 316        倒扣的王牌      (1951)         N/A  111 min
# 631         白色緞帶      (2009)           R  144 min
# 302       阿爾及爾之戰      (1966)         N/A  121 min
# 819         關鍵報告      (2002)       PG-13  145 min
# 116         疤面煞星      (1983)        R-18  170 min
# 460        波坦金戰艦      (1925)         N/A   75 min
#
#                                       genre rating   votes        gross
# 226    \nComedy, Drama, Romance                8.1   80887    2,804,874
# 768  \nDrama, History, Thriller                7.7  171760          N/A
# 514        \nComedy, Drama, War                7.9   46929    1,059,830
# 103             \nDrama, Family                8.3  188974    1,223,869
# ...
